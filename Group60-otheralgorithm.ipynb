# %% [markdown]
# ## 1 Instruction of running the code
# ### 1.1 Important libraries & Version control
# Google Colab:
# Python 3.7.13
# Sklearn 1.0.2
# Tensorflow/Keras 2.80
# ### 1.2 Running environment
# The python code is tested and running under the environment of both anaconda and google colab. The computational power of the CPU would decide how long the code will run and be aware the dataset is pulled from the internet so make sure your device has a connection to it. The process time may vary from different versions of google colab such that the pro version would assign more memory/cpu/gpu. The local environment is anaconda 4.12.0 under Windows 11 with CPU of i7-117800H and 16G RAM.
# ### 1.3 Directory of tuning result
# It is highly recommended that before you start tuning hyperparameters in the LSTM model, put a directory to your own location in the tuner definition. This provides a safe location and avoids authentication problems if you are running anaconda without administrator mode that blocks you from creating a file folder in a relative directory automatically. Moreover, reproduction of tuning results can be covered by the file stored as well.
# ### 1.4 How to successfully run the code
# It is recommended to run ipynb by running from top to bottom through each code block. For an ease of running best model only, you may want to skip the hyperparameters tuning section just to avoid the massive processing time.

# %% [markdown]
# ### 1.5 Helpful command to install and upgrade packages

# %%
# !pip install xgboost
# !pip install yfinance
# !pip install -q -U keras-tuner
# !pip install --upgrade pandas
# !pip install --upgrade pandas-datareader
# Out:
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (0.90)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from xgboost) (1.21.6)
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.6)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.8.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: pandas-datareader in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (2.27.1)
# Requirement already satisfied: pandas>=0.23 in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (1.3.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pandas-datareader) (4.8.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.23->pandas-datareader) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.23->pandas-datareader) (1.15.0)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pandas-datareader) (2021.10.8)

# %% [markdown]
# ### 1.6 Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import yfinance as yf
import xgboost as xgb
# For reading stock data
import pandas_datareader.data as web
from sklearn.preprocessing import MinMaxScaler
# For time stamps
from datetime import datetime
# For data pre-processing
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeRegressor
# Grid Search
from sklearn.model_selection import GridSearchCV
from sklearn.neighbors import NearestNeighbors, KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import accuracy_score 
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR

# LSTM
import math
import keras_tuner
from tensorflow import keras
from sklearn.preprocessing import MinMaxScaler
from keras.models import save_model
from keras.models import model_from_json
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters
from tensorflow.keras import optimizers,datasets

# %% [markdown]
# ### 4.7 Set the maximum number of rows and columns can be viewed

# %%
pd.set_option('display.max_rows', None)  # Set the maximum number of rows that can be viewed
pd.set_option('display.max_columns', None)  # Set the maximum number of columns that can be viewed

# %% [markdown]
# ## 2 Data Preprocessing

# %% [markdown]
# ### 2.1 Download the latest five-year data to 08/05/2022

# %%
# Pull stock price of APPLE in 5 years 
end = datetime(2022, 5, 8)
start = datetime(end.year - 5, end.month, end.day)
# using DataReader to read the stock price from start point to end point
df = yf.download('AAPL', start=start, end=end)
df = df.reset_index(level=0)
print(df.head())
print(df.info())
# Out:
# [*********************100%***********************]  1 of 1 completed
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2017-05-08  37.257500  38.424999  37.257500  38.252499  36.063488  195009600
# 1 2017-05-09  38.467499  38.720001  38.362499  38.497501  36.294476  156521600
# 2 2017-05-10  38.407501  38.485001  38.027500  38.314999  36.122414  103222800
# 3 2017-05-11  38.112499  38.517502  38.077499  38.487499  36.434814  109020400
# 4 2017-05-12  38.674999  39.105000  38.667500  39.025002  36.943645  130108000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1260 entries, 0 to 1259
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1260 non-null   datetime64[ns]
#  1   Open       1260 non-null   float64
#  2   High       1260 non-null   float64
#  3   Low        1260 non-null   float64
#  4   Close      1260 non-null   float64
#  5   Adj Close  1260 non-null   float64
#  6   Volume     1260 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 69.0 KB
# None

# %%
df.shape
# Out:
# (1260, 7)

# %% [markdown]
# ### 2.2 Generate extra features to analyze data

# %% [markdown]
# We want to know the year, month, day, week of the year, and day of the week corresponding to Date, try to find the correlations between time characteristics and closing prices

# %%
#Generate the year, month, day, week of the year, and day of the week corresponding to Date
df["Date"] = pd.to_datetime(df["Date"])
df["DayOfYear"] = df["Date"].dt.dayofyear
df["day"] = df["Date"].dt.day
df["month"] = df["Date"].dt.month
df["year"] = df["Date"].dt.year
df["weekday"] = df["Date"].dt.weekday
df["week"] = df["Date"].dt.week

# Adjust the position of columns
df = df[['Date', 'High', 'Low', 'Open', 'Volume', 'DayOfYear', 'day',
         'month', 'year', 'weekday', 'week', 'Close']]
# View all columns
print(df.columns)

print(df.head())

# View shape of df
print(df.shape)
# Out:
# Index(['Date', 'High', 'Low', 'Open', 'Volume', 'DayOfYear', 'day', 'month',
#        'year', 'weekday', 'week', 'Close'],
#       dtype='object')
#         Date       High        Low       Open     Volume  DayOfYear  day  \
# 0 2017-05-08  38.424999  37.257500  37.257500  195009600        128    8
# 1 2017-05-09  38.720001  38.362499  38.467499  156521600        129    9
# 2 2017-05-10  38.485001  38.027500  38.407501  103222800        130   10
# 3 2017-05-11  38.517502  38.077499  38.112499  109020400        131   11
# 4 2017-05-12  39.105000  38.667500  38.674999  130108000        132   12
#
#    month  year  weekday  week      Close
# 0      5  2017        0    19  38.252499
# 1      5  2017        1    19  38.497501
# 2      5  2017        2    19  38.314999
# 3      5  2017        3    19  38.487499
# 4      5  2017        4    19  39.025002
# (1260, 12)
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:8: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %% [markdown]
# ### 2.3 The function of generate plots to analyse data

# %% [markdown]
# We plot the close price and different time features to visualize the relationships, using the feature generated above

# %%
# generate plots
def generatePlot(train_data):
    plt.subplots(figsize=(30, 25))
    plt.title("heatmap of features")
    sns.heatmap(train_data[::500].corr(), cmap="YlGnBu", annot=True, vmin=-0.1, vmax=0.4, center=0)
    plt.show()

    close_weekday = train_data.groupby("weekday", as_index=False)["Close"].mean()
    sns.lineplot(data=close_weekday, x="weekday", y="Close")
    plt.show()

    close_day = train_data.groupby("day", as_index=False)["Close"].mean()
    sns.lineplot(data=close_day, x="day", y="Close")
    plt.show()

    close_month = train_data.groupby("month", as_index=False)["Close"].mean()
    sns.lineplot(data=close_month, x="month", y="Close")
    plt.show()

    sns.lineplot(data=train_data, x="Date", y="Close" )
    plt.show()

    sns.boxplot(data=train_data, x="weekday", y="Close")
    plt.show()
generatePlot(df)

# %%
# delete "Date" feature
df.drop(["Date"], axis=1, inplace=True)

# %% [markdown]
# ### 2.4 Pre-process the numeric data of stocks

# %% [markdown]
# We choose Min-MaxScaler function to normalize the numeric data, instead of time features

# %%
# definite the preprocessing function, choosing "High", "Low", "Open", "Volume", "Close" features
def preprocessing(df):
    scaler = MinMaxScaler(feature_range=(0, 1))
    transformed_data = scaler.fit_transform(df[["High", "Low", "Open", "Volume", "Close"]])

    df["High"] = transformed_data[:, 0]
    df["Low"] = transformed_data[:, 1]
    df["Open"] = transformed_data[:, 2]
    df["Volume"] = transformed_data[:, 3]

    scaler_close = MinMaxScaler(feature_range=(0, 1))
    transformed_close = scaler_close.fit_transform(df[["Close"]])

    df["Close"] = transformed_close
    return scaler, scaler_close


scaler, scaler_close = preprocessing(df)

data_np = df.values

# %% [markdown]
# ### 2.5 Adding features because using time series-based LSTM model

# %% [markdown]
# Since we use a time series-based LSTM model for prediction, we add the first 60 days of each day as new features to each row of the dataset, so the shape of the dataset is reduced by 60 rows, conversely adding relative columns.

# %%
# Use the close price of the past_days days as a feature
data = []
past_days = 60

for i in range(60, df.shape[0]):
    # Concatenate the i-th row of data_np
    # Put the close price of the previous past_days days as a feature and put it into the feature of the i-th day
    data.append(np.hstack((data_np[i - past_days:i, -1], data_np[i])).tolist())

data = np.array(data)
print(data.shape)
# Out:
# (1200, 71)

# %% [markdown]
# ### 2.6 Divide training set and test set

# %% [markdown]
# We choose 80% of dataset to become training set and 20% to become test set

# %%
split = 0.8
# Use sklearn method to divide training set and test set
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data[:, :-1], data[:, -1], test_size=1 - split, random_state=32)

# %% [markdown]
# ## 3 SVM model

# %%
# train the svm regression model
svm_regressor = SVR(kernel="linear", C=0.1, gamma='scale')
svm_regressor.fit(X_train, y_train)
y_hat = svm_regressor.predict(X_test)
y_test_inver = scaler_close.inverse_transform([y_test])
y_hat_inver = scaler_close.inverse_transform([y_hat])
# computing mse
mse = np.mean((y_test_inver - y_hat_inver) ** 2)
print('best mse:', mse)

#plot a plot figure to show the difference between predicted and actual labels
a = pd.DataFrame({'Close': y_hat_inver[0,:], 'Type': 'Predicted'})
a = a.append(pd.DataFrame({'Close': y_test_inver[0,:], 'Type': 'Actual'}))
a = a.reset_index()
sns.lineplot(data=a, x="index", y="Close", hue="Type")
plt.show()
# Out:
# 35.41506061852441

# %% [markdown]
# ### 3.1 Use grid search to find the best parameter of SVM model

# %%
param_grid = {'kernel': ['rbf','linear','sigmoid'],
              'C': [0.1, 1, 100, 200, 1000],
              'gamma': ['scale', 'auto']}
print("Parameter grid:\n{}".format(param_grid))
grid_search = GridSearchCV(SVR(), param_grid, cv=5,
                           return_train_score=True, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best parameters: {}".format(grid_search.best_params_))
print("Best cross-validation score: {}".format(grid_search.best_score_))
print("Best estimator: {}".format(grid_search.best_estimator_))
# Out:
# Parameter grid:
# {'kernel': ['linear'], 'C': [0.02, 0.04, 0.06, 0.08, 0.1, 0.12, 0.14, 0.16, 1, 10, 100], 'gamma': ['scale', 'auto']}
# Best parameters: {'C': 0.1, 'gamma': 'scale', 'kernel': 'linear'}
# Best cross-validation score: 0.9827585584168658
# Best estimator: SVR(C=0.1, kernel='linear')

# %% [markdown]
# ## 4 RandomForest model

# %%
model_random_forest = RandomForestRegressor(n_estimators =70, max_depth = 7, random_state=32)
#  train the random forest regression model
model_random_forest.fit(X_train, y_train)
y_hat = model_random_forest.predict(X_test)
y_test_inver = scaler_close.inverse_transform([y_test])
y_hat_inver = scaler_close.inverse_transform([y_hat])

# computing mse
mse = np.mean((y_test_inver - y_hat_inver) ** 2)
print('best mse:',mse)

#plot a plot figure to show the difference between predicted and actual labels
a = pd.DataFrame({'Close': y_hat_inver[0, :], 'Type': 'Predicted'})
a = a.append(pd.DataFrame({'Close': y_test_inver[0, :], 'Type': 'Actual'}))
a = a.reset_index()

sns.lineplot(data=a, x="index", y="Close", hue="Type")
plt.show()
# Out:
# 1.3757713016979776

# %% [markdown]
# ### 4.1 Use grid search to find the best parameter

# %%
param_grid = {'n_estimators': [35, 40, 50, 60, 70], 'max_depth': [5, 6, 7, 12]}
print("Parameter grid:\n{}".format(param_grid))
grid_search = GridSearchCV(RandomForestRegressor(random_state=32), param_grid, cv=5,
                           return_train_score=True, n_jobs=-1)
grid_search.fit(X_train, y_train)
print("Best parameters: {}".format(grid_search.best_params_))
print("Best cross-validation score: {}".format(grid_search.best_score_))
print("Best estimator:\n{}".format(grid_search.best_estimator_))
# Out:
# Parameter grid:
# {'n_estimators': [120, 125, 130, 135], 'max_depth': [7, 8, 9, 10, 11]}
# Best parameters: {'max_depth': 8, 'n_estimators': 125}
# Best cross-validation score: 0.9993962292237443
# Best estimator:
# RandomForestRegressor(max_depth=8, n_estimators=125)

# %% [markdown]
# ### 4.2 Train XGboostmodel to predict data

# %%
def xgboost(x_train_v, y_train_v, x_valid, y_valid):
    print("Start training xgboost model...")
    y_train_v = np.log(1 + y_train_v)
    y_valid = np.log(1 + y_valid)
    train_matrix = xgb.DMatrix(x_train_v, y_train_v)
    valid_matrix = xgb.DMatrix(x_valid, y_valid)

    param = {'max_depth':4,
             'eta': 0.06,
             'gamma': 0.0001,
             'subsample': 0.75,
             'colsample_bytree': 0.6,
             'objective': 'reg:squarederror', }
    params = list(param.items())
    num_boost_round = 10000
    evals = [(train_matrix, 'train'), (valid_matrix, 'valid')]
    reg = xgb.train(params, train_matrix, num_boost_round, evals,
                    verbose_eval=1, early_stopping_rounds=100)

    y_valid_hat = reg.predict(valid_matrix)
    y_valid_hat = (np.exp(y_valid_hat) - 1)

    y_test_inver = scaler_close.inverse_transform([y_test])
    y_hat_inver = scaler_close.inverse_transform([y_valid_hat])
    # 计算mse
    mse = np.mean((y_test_inver - y_hat_inver) ** 2)
    print(mse)
    a = pd.DataFrame({'Close': y_hat_inver[0, :], 'Type': 'Predicted'})
    a = a.append(pd.DataFrame({'Close': y_test_inver[0, :], 'Type': 'Actual'}))
    a = a.reset_index()

    sns.lineplot(data=a, x="index", y="Close", hue="Type")
    plt.show()


xgboost(X_train, y_train, X_test, y_test)
# Out:
# Start training xgboost model...
# [0]	train-rmse:0.294886	valid-rmse:0.309891
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 100 rounds.
# [1]	train-rmse:0.277376	valid-rmse:0.291462
# [2]	train-rmse:0.260928	valid-rmse:0.274159
# [3]	train-rmse:0.245445	valid-rmse:0.257831
# [4]	train-rmse:0.230905	valid-rmse:0.242504
# [5]	train-rmse:0.217245	valid-rmse:0.228155
# [6]	train-rmse:0.20439	valid-rmse:0.214644
# [7]	train-rmse:0.192265	valid-rmse:0.201898
# [8]	train-rmse:0.180898	valid-rmse:0.189883
# [9]	train-rmse:0.170213	valid-rmse:0.178665
# [10]	train-rmse:0.160123	valid-rmse:0.168083
# [11]	train-rmse:0.150667	valid-rmse:0.158215
# [12]	train-rmse:0.14175	valid-rmse:0.148844
# [13]	train-rmse:0.133379	valid-rmse:0.140053
# [14]	train-rmse:0.125476	valid-rmse:0.131789
# [15]	train-rmse:0.118051	valid-rmse:0.123997
# [16]	train-rmse:0.111067	valid-rmse:0.11673
# [17]	train-rmse:0.104498	valid-rmse:0.109858
# [18]	train-rmse:0.098368	valid-rmse:0.103464
# [19]	train-rmse:0.092572	valid-rmse:0.097386
# [20]	train-rmse:0.087106	valid-rmse:0.091665
# [21]	train-rmse:0.081966	valid-rmse:0.086266
# [22]	train-rmse:0.077111	valid-rmse:0.08117
# [23]	train-rmse:0.072572	valid-rmse:0.07637
# [24]	train-rmse:0.06829	valid-rmse:0.071914
# [25]	train-rmse:0.064274	valid-rmse:0.067713
# [26]	train-rmse:0.060483	valid-rmse:0.063732
# [27]	train-rmse:0.056916	valid-rmse:0.060008
# [28]	train-rmse:0.053575	valid-rmse:0.056516
# [29]	train-rmse:0.050413	valid-rmse:0.053216
# [30]	train-rmse:0.047436	valid-rmse:0.050091
# [31]	train-rmse:0.044655	valid-rmse:0.047182
# [32]	train-rmse:0.042024	valid-rmse:0.044415
# [33]	train-rmse:0.039556	valid-rmse:0.04185
# [34]	train-rmse:0.03724	valid-rmse:0.039403
# [35]	train-rmse:0.035048	valid-rmse:0.037095
# [36]	train-rmse:0.03299	valid-rmse:0.034923
# [37]	train-rmse:0.031065	valid-rmse:0.032908
# [38]	train-rmse:0.02925	valid-rmse:0.031006
# [39]	train-rmse:0.027546	valid-rmse:0.029228
# [40]	train-rmse:0.025945	valid-rmse:0.027559
# [41]	train-rmse:0.024445	valid-rmse:0.025989
# [42]	train-rmse:0.023032	valid-rmse:0.024518
# [43]	train-rmse:0.021702	valid-rmse:0.023124
# [44]	train-rmse:0.02045	valid-rmse:0.021825
# [45]	train-rmse:0.019276	valid-rmse:0.020611
# [46]	train-rmse:0.018179	valid-rmse:0.01948
# [47]	train-rmse:0.017137	valid-rmse:0.018402
# [48]	train-rmse:0.016162	valid-rmse:0.017405
# [49]	train-rmse:0.015244	valid-rmse:0.016475
# [50]	train-rmse:0.014385	valid-rmse:0.015593
# [51]	train-rmse:0.01358	valid-rmse:0.01477
# [52]	train-rmse:0.012824	valid-rmse:0.01401
# [53]	train-rmse:0.012117	valid-rmse:0.013308
# [54]	train-rmse:0.011457	valid-rmse:0.01265
# [55]	train-rmse:0.010831	valid-rmse:0.012041
# [56]	train-rmse:0.010244	valid-rmse:0.011467
# [57]	train-rmse:0.009704	valid-rmse:0.010948
# [58]	train-rmse:0.009192	valid-rmse:0.010464
# [59]	train-rmse:0.00871	valid-rmse:0.010016
# [60]	train-rmse:0.008257	valid-rmse:0.009582
# [61]	train-rmse:0.007839	valid-rmse:0.009204
# [62]	train-rmse:0.007451	valid-rmse:0.008845
# [63]	train-rmse:0.007095	valid-rmse:0.008528
# [64]	train-rmse:0.006756	valid-rmse:0.008237
# [65]	train-rmse:0.006435	valid-rmse:0.007962
# [66]	train-rmse:0.006138	valid-rmse:0.007714
# [67]	train-rmse:0.005862	valid-rmse:0.007478
# [68]	train-rmse:0.005611	valid-rmse:0.007277
# [69]	train-rmse:0.005371	valid-rmse:0.007083
# [70]	train-rmse:0.005157	valid-rmse:0.006921
# [71]	train-rmse:0.004957	valid-rmse:0.006773
# [72]	train-rmse:0.004776	valid-rmse:0.00663
# [73]	train-rmse:0.004595	valid-rmse:0.006499
# [74]	train-rmse:0.004442	valid-rmse:0.00639
# [75]	train-rmse:0.004293	valid-rmse:0.00629
# [76]	train-rmse:0.004164	valid-rmse:0.006189
# [77]	train-rmse:0.004043	valid-rmse:0.00611
# [78]	train-rmse:0.003931	valid-rmse:0.00603
# [79]	train-rmse:0.003829	valid-rmse:0.005964
# [80]	train-rmse:0.003725	valid-rmse:0.005899
# [81]	train-rmse:0.003646	valid-rmse:0.005851
# [82]	train-rmse:0.003569	valid-rmse:0.005803
# [83]	train-rmse:0.003498	valid-rmse:0.005757
# [84]	train-rmse:0.003428	valid-rmse:0.005715
# [85]	train-rmse:0.003367	valid-rmse:0.005687
# [86]	train-rmse:0.003306	valid-rmse:0.005649
# [87]	train-rmse:0.003256	valid-rmse:0.005621
# [88]	train-rmse:0.00321	valid-rmse:0.005598
# [89]	train-rmse:0.003168	valid-rmse:0.005565
# [90]	train-rmse:0.003133	valid-rmse:0.005543
# [91]	train-rmse:0.003093	valid-rmse:0.005526
# [92]	train-rmse:0.00306	valid-rmse:0.005511
# [93]	train-rmse:0.003025	valid-rmse:0.005508
# [94]	train-rmse:0.002995	valid-rmse:0.005494
# [95]	train-rmse:0.002977	valid-rmse:0.005485
# [96]	train-rmse:0.002956	valid-rmse:0.005477
# [97]	train-rmse:0.002937	valid-rmse:0.005468
# [98]	train-rmse:0.002919	valid-rmse:0.00546
# [99]	train-rmse:0.002908	valid-rmse:0.005455
# [100]	train-rmse:0.002891	valid-rmse:0.005448
# [101]	train-rmse:0.002878	valid-rmse:0.005442
# [102]	train-rmse:0.002865	valid-rmse:0.005442
# [103]	train-rmse:0.002853	valid-rmse:0.005438
# [104]	train-rmse:0.002847	valid-rmse:0.005432
# [105]	train-rmse:0.002839	valid-rmse:0.005428
# [106]	train-rmse:0.002832	valid-rmse:0.005422
# [107]	train-rmse:0.002824	valid-rmse:0.005418
# [108]	train-rmse:0.002819	valid-rmse:0.005418
# [109]	train-rmse:0.002809	valid-rmse:0.005413
# [110]	train-rmse:0.002805	valid-rmse:0.005411
# [111]	train-rmse:0.002804	valid-rmse:0.005411
# [112]	train-rmse:0.002803	valid-rmse:0.00541
# [113]	train-rmse:0.002797	valid-rmse:0.005407
# [114]	train-rmse:0.002792	valid-rmse:0.005406
# [115]	train-rmse:0.002789	valid-rmse:0.005405
# [116]	train-rmse:0.002783	valid-rmse:0.005411
# [117]	train-rmse:0.002776	valid-rmse:0.00541
# [118]	train-rmse:0.00277	valid-rmse:0.005413
# [119]	train-rmse:0.002768	valid-rmse:0.005412
# [120]	train-rmse:0.002765	valid-rmse:0.005411
# [121]	train-rmse:0.002765	valid-rmse:0.005411
# [122]	train-rmse:0.002761	valid-rmse:0.005409
# [123]	train-rmse:0.00276	valid-rmse:0.005409
# [124]	train-rmse:0.002756	valid-rmse:0.005404
# [125]	train-rmse:0.002756	valid-rmse:0.005404
# [126]	train-rmse:0.002754	valid-rmse:0.005403
# [127]	train-rmse:0.002754	valid-rmse:0.005403
# [128]	train-rmse:0.002753	valid-rmse:0.005404
# [129]	train-rmse:0.002745	valid-rmse:0.00541
# [130]	train-rmse:0.002745	valid-rmse:0.00541
# [131]	train-rmse:0.002745	valid-rmse:0.00541
# [132]	train-rmse:0.002745	valid-rmse:0.00541
# [133]	train-rmse:0.002745	valid-rmse:0.00541
# [134]	train-rmse:0.00274	valid-rmse:0.005405
# [135]	train-rmse:0.00274	valid-rmse:0.005405
# [136]	train-rmse:0.002736	valid-rmse:0.0054
# [137]	train-rmse:0.002736	valid-rmse:0.0054
# [138]	train-rmse:0.002736	valid-rmse:0.0054
# [139]	train-rmse:0.002736	valid-rmse:0.0054
# [140]	train-rmse:0.002736	valid-rmse:0.0054
# [141]	train-rmse:0.002736	valid-rmse:0.0054
# [142]	train-rmse:0.002736	valid-rmse:0.0054
# [143]	train-rmse:0.002729	valid-rmse:0.005398
# [144]	train-rmse:0.002729	valid-rmse:0.005398
# [145]	train-rmse:0.002722	valid-rmse:0.005399
# [146]	train-rmse:0.002722	valid-rmse:0.005399
# [147]	train-rmse:0.002722	valid-rmse:0.005399
# [148]	train-rmse:0.002715	valid-rmse:0.005398
# [149]	train-rmse:0.002715	valid-rmse:0.005397
# [150]	train-rmse:0.002715	valid-rmse:0.005397
# [151]	train-rmse:0.00271	valid-rmse:0.005396
# [152]	train-rmse:0.00271	valid-rmse:0.005396
# [153]	train-rmse:0.00271	valid-rmse:0.005396
# [154]	train-rmse:0.002706	valid-rmse:0.005392
# [155]	train-rmse:0.002706	valid-rmse:0.005392
# [156]	train-rmse:0.002701	valid-rmse:0.005396
# [157]	train-rmse:0.002701	valid-rmse:0.005396
# [158]	train-rmse:0.002701	valid-rmse:0.005396
# [159]	train-rmse:0.002701	valid-rmse:0.005396
# [160]	train-rmse:0.002701	valid-rmse:0.005396
# [161]	train-rmse:0.002701	valid-rmse:0.005396
# [162]	train-rmse:0.002701	valid-rmse:0.005396
# [163]	train-rmse:0.002701	valid-rmse:0.005396
# [164]	train-rmse:0.002701	valid-rmse:0.005396
# [165]	train-rmse:0.002701	valid-rmse:0.005396
# [166]	train-rmse:0.002701	valid-rmse:0.005396
# [167]	train-rmse:0.002693	valid-rmse:0.005394
# [168]	train-rmse:0.002693	valid-rmse:0.005394
# [169]	train-rmse:0.002693	valid-rmse:0.005395
# [170]	train-rmse:0.002693	valid-rmse:0.005394
# [171]	train-rmse:0.002693	valid-rmse:0.005395
# [172]	train-rmse:0.002693	valid-rmse:0.005395
# [173]	train-rmse:0.002693	valid-rmse:0.005395
# [174]	train-rmse:0.002693	valid-rmse:0.005395
# [175]	train-rmse:0.002693	valid-rmse:0.005395
# [176]	train-rmse:0.002693	valid-rmse:0.005394
# [177]	train-rmse:0.002693	valid-rmse:0.005394
# [178]	train-rmse:0.002693	valid-rmse:0.005394
# [179]	train-rmse:0.002693	valid-rmse:0.005394
# [180]	train-rmse:0.002693	valid-rmse:0.005394
# [181]	train-rmse:0.002693	valid-rmse:0.005394
# [182]	train-rmse:0.002693	valid-rmse:0.005394
# [183]	train-rmse:0.002693	valid-rmse:0.005394
# [184]	train-rmse:0.002693	valid-rmse:0.005394
# [185]	train-rmse:0.002688	valid-rmse:0.005383
# [186]	train-rmse:0.002688	valid-rmse:0.005383
# [187]	train-rmse:0.002688	valid-rmse:0.005383
# [188]	train-rmse:0.002688	valid-rmse:0.005383
# [189]	train-rmse:0.002688	valid-rmse:0.005383
# [190]	train-rmse:0.002688	valid-rmse:0.005383
# [191]	train-rmse:0.002688	valid-rmse:0.005383
# [192]	train-rmse:0.002688	valid-rmse:0.005383
# [193]	train-rmse:0.002688	valid-rmse:0.005383
# [194]	train-rmse:0.002688	valid-rmse:0.005383
# [195]	train-rmse:0.002682	valid-rmse:0.005386
# [196]	train-rmse:0.002682	valid-rmse:0.005386
# [197]	train-rmse:0.002682	valid-rmse:0.005386
# [198]	train-rmse:0.002682	valid-rmse:0.005386
# [199]	train-rmse:0.002682	valid-rmse:0.005386
# [200]	train-rmse:0.002682	valid-rmse:0.005386
# [201]	train-rmse:0.002682	valid-rmse:0.005386
# [202]	train-rmse:0.002682	valid-rmse:0.005386
# [203]	train-rmse:0.002682	valid-rmse:0.005386
# [204]	train-rmse:0.002682	valid-rmse:0.005386
# [205]	train-rmse:0.002682	valid-rmse:0.005386
# [206]	train-rmse:0.002682	valid-rmse:0.005386
# [207]	train-rmse:0.002682	valid-rmse:0.005386
# [208]	train-rmse:0.002682	valid-rmse:0.005386
# [209]	train-rmse:0.002682	valid-rmse:0.005386
# [210]	train-rmse:0.002682	valid-rmse:0.005386
# [211]	train-rmse:0.002682	valid-rmse:0.005386
# [212]	train-rmse:0.002682	valid-rmse:0.005386
# [213]	train-rmse:0.002677	valid-rmse:0.005383
# [214]	train-rmse:0.002677	valid-rmse:0.005383
# [215]	train-rmse:0.002677	valid-rmse:0.005383
# [216]	train-rmse:0.002677	valid-rmse:0.005383
# [217]	train-rmse:0.002677	valid-rmse:0.005383
# [218]	train-rmse:0.002677	valid-rmse:0.005383
# [219]	train-rmse:0.002677	valid-rmse:0.005383
# [220]	train-rmse:0.002677	valid-rmse:0.005383
# [221]	train-rmse:0.002677	valid-rmse:0.005383
# [222]	train-rmse:0.002677	valid-rmse:0.005383
# [223]	train-rmse:0.002677	valid-rmse:0.005383
# [224]	train-rmse:0.002677	valid-rmse:0.005383
# [225]	train-rmse:0.002677	valid-rmse:0.005383
# [226]	train-rmse:0.002677	valid-rmse:0.005383
# [227]	train-rmse:0.002677	valid-rmse:0.005383
# [228]	train-rmse:0.002677	valid-rmse:0.005383
# [229]	train-rmse:0.002677	valid-rmse:0.005383
# [230]	train-rmse:0.002677	valid-rmse:0.005383
# [231]	train-rmse:0.002677	valid-rmse:0.005383
# [232]	train-rmse:0.002677	valid-rmse:0.005383
# [233]	train-rmse:0.002677	valid-rmse:0.005383
# [234]	train-rmse:0.002677	valid-rmse:0.005383
# [235]	train-rmse:0.002673	valid-rmse:0.005377
# [236]	train-rmse:0.002673	valid-rmse:0.005377
# [237]	train-rmse:0.002673	valid-rmse:0.005377
# [238]	train-rmse:0.002673	valid-rmse:0.005377
# [239]	train-rmse:0.002673	valid-rmse:0.005377
# [240]	train-rmse:0.002673	valid-rmse:0.005377
# [241]	train-rmse:0.002673	valid-rmse:0.005377
# [242]	train-rmse:0.002673	valid-rmse:0.005377
# [243]	train-rmse:0.002673	valid-rmse:0.005377
# [244]	train-rmse:0.002673	valid-rmse:0.005377
# [245]	train-rmse:0.002673	valid-rmse:0.005377
# [246]	train-rmse:0.002673	valid-rmse:0.005377
# [247]	train-rmse:0.002673	valid-rmse:0.005377
# [248]	train-rmse:0.002673	valid-rmse:0.005377
# [249]	train-rmse:0.002673	valid-rmse:0.005377
# [250]	train-rmse:0.002673	valid-rmse:0.005377
# [251]	train-rmse:0.002673	valid-rmse:0.005377
# [252]	train-rmse:0.002668	valid-rmse:0.005372
# [253]	train-rmse:0.002661	valid-rmse:0.005369
# [254]	train-rmse:0.002661	valid-rmse:0.005369
# [255]	train-rmse:0.002661	valid-rmse:0.005369
# [256]	train-rmse:0.002661	valid-rmse:0.005369
# [257]	train-rmse:0.002661	valid-rmse:0.005369
# [258]	train-rmse:0.002653	valid-rmse:0.005365
# [259]	train-rmse:0.002653	valid-rmse:0.005365
# [260]	train-rmse:0.002649	valid-rmse:0.005362
# [261]	train-rmse:0.002649	valid-rmse:0.005362
# [262]	train-rmse:0.002649	valid-rmse:0.005362
# [263]	train-rmse:0.002649	valid-rmse:0.005362
# [264]	train-rmse:0.002643	valid-rmse:0.005359
# [265]	train-rmse:0.002643	valid-rmse:0.005359
# [266]	train-rmse:0.002643	valid-rmse:0.005359
# [267]	train-rmse:0.002643	valid-rmse:0.005359
# [268]	train-rmse:0.002643	valid-rmse:0.005359
# [269]	train-rmse:0.00264	valid-rmse:0.005358
# [270]	train-rmse:0.00264	valid-rmse:0.005358
# [271]	train-rmse:0.002637	valid-rmse:0.00536
# [272]	train-rmse:0.002633	valid-rmse:0.00536
# [273]	train-rmse:0.002633	valid-rmse:0.00536
# [274]	train-rmse:0.002633	valid-rmse:0.00536
# [275]	train-rmse:0.002633	valid-rmse:0.00536
# [276]	train-rmse:0.002633	valid-rmse:0.00536
# [277]	train-rmse:0.002633	valid-rmse:0.00536
# [278]	train-rmse:0.002633	valid-rmse:0.00536
# [279]	train-rmse:0.002633	valid-rmse:0.00536
# [280]	train-rmse:0.002633	valid-rmse:0.00536
# [281]	train-rmse:0.002633	valid-rmse:0.00536
# [282]	train-rmse:0.002629	valid-rmse:0.005362
# [283]	train-rmse:0.002629	valid-rmse:0.005362
# [284]	train-rmse:0.002629	valid-rmse:0.005362
# [285]	train-rmse:0.002629	valid-rmse:0.005362
# [286]	train-rmse:0.002629	valid-rmse:0.005362
# [287]	train-rmse:0.002629	valid-rmse:0.005362
# [288]	train-rmse:0.002629	valid-rmse:0.005362
# [289]	train-rmse:0.002629	valid-rmse:0.005362
# [290]	train-rmse:0.002629	valid-rmse:0.005362
# [291]	train-rmse:0.002629	valid-rmse:0.005362
# [292]	train-rmse:0.002623	valid-rmse:0.005366
# [293]	train-rmse:0.002623	valid-rmse:0.005366
# [294]	train-rmse:0.002623	valid-rmse:0.005366
# [295]	train-rmse:0.002623	valid-rmse:0.005366
# [296]	train-rmse:0.002623	valid-rmse:0.005366
# [297]	train-rmse:0.002623	valid-rmse:0.005366
# [298]	train-rmse:0.002623	valid-rmse:0.005367
# [299]	train-rmse:0.002623	valid-rmse:0.005367
# [300]	train-rmse:0.002623	valid-rmse:0.005367
# [301]	train-rmse:0.002623	valid-rmse:0.005367
# [302]	train-rmse:0.002623	valid-rmse:0.005367
# [303]	train-rmse:0.002623	valid-rmse:0.005366
# [304]	train-rmse:0.002623	valid-rmse:0.005367
# [305]	train-rmse:0.002623	valid-rmse:0.005367
# [306]	train-rmse:0.002623	valid-rmse:0.005367
# [307]	train-rmse:0.002623	valid-rmse:0.005366
# [308]	train-rmse:0.002623	valid-rmse:0.005366
# [309]	train-rmse:0.002623	valid-rmse:0.005366
# [310]	train-rmse:0.002623	valid-rmse:0.005366
# [311]	train-rmse:0.002623	valid-rmse:0.005366
# [312]	train-rmse:0.002623	valid-rmse:0.005366
# [313]	train-rmse:0.002623	valid-rmse:0.005366
# [314]	train-rmse:0.002623	valid-rmse:0.005366
# [315]	train-rmse:0.002623	valid-rmse:0.005366
# [316]	train-rmse:0.002623	valid-rmse:0.005366
# [317]	train-rmse:0.002623	valid-rmse:0.005366
# [318]	train-rmse:0.002623	valid-rmse:0.005366
# [319]	train-rmse:0.002617	valid-rmse:0.005364
# [320]	train-rmse:0.002617	valid-rmse:0.005364
# [321]	train-rmse:0.002617	valid-rmse:0.005364
# [322]	train-rmse:0.002617	valid-rmse:0.005364
# [323]	train-rmse:0.002617	valid-rmse:0.005364
# [324]	train-rmse:0.002614	valid-rmse:0.005364
# [325]	train-rmse:0.002614	valid-rmse:0.005364
# [326]	train-rmse:0.002614	valid-rmse:0.005364
# [327]	train-rmse:0.002614	valid-rmse:0.005364
# [328]	train-rmse:0.002614	valid-rmse:0.005364
# [329]	train-rmse:0.002614	valid-rmse:0.005364
# [330]	train-rmse:0.002614	valid-rmse:0.005364
# [331]	train-rmse:0.002614	valid-rmse:0.005364
# [332]	train-rmse:0.002614	valid-rmse:0.005364
# [333]	train-rmse:0.002614	valid-rmse:0.005364
# [334]	train-rmse:0.002614	valid-rmse:0.005364
# [335]	train-rmse:0.002614	valid-rmse:0.005364
# [336]	train-rmse:0.002614	valid-rmse:0.005364
# [337]	train-rmse:0.002614	valid-rmse:0.005364
# [338]	train-rmse:0.002614	valid-rmse:0.005364
# [339]	train-rmse:0.002614	valid-rmse:0.005364
# [340]	train-rmse:0.002614	valid-rmse:0.005364
# [341]	train-rmse:0.002614	valid-rmse:0.005364
# [342]	train-rmse:0.002614	valid-rmse:0.005364
# [343]	train-rmse:0.002614	valid-rmse:0.005364
# [344]	train-rmse:0.002611	valid-rmse:0.005366
# [345]	train-rmse:0.002611	valid-rmse:0.005366
# [346]	train-rmse:0.002611	valid-rmse:0.005366
# [347]	train-rmse:0.002611	valid-rmse:0.005366
# [348]	train-rmse:0.002611	valid-rmse:0.005366
# [349]	train-rmse:0.002607	valid-rmse:0.005365
# [350]	train-rmse:0.002607	valid-rmse:0.005365
# [351]	train-rmse:0.002607	valid-rmse:0.005365
# [352]	train-rmse:0.002607	valid-rmse:0.005365
# [353]	train-rmse:0.002604	valid-rmse:0.005368
# [354]	train-rmse:0.002604	valid-rmse:0.005368
# [355]	train-rmse:0.002599	valid-rmse:0.00537
# [356]	train-rmse:0.002593	valid-rmse:0.005368
# [357]	train-rmse:0.002593	valid-rmse:0.005368
# [358]	train-rmse:0.002593	valid-rmse:0.005368
# [359]	train-rmse:0.002593	valid-rmse:0.005368
# [360]	train-rmse:0.002588	valid-rmse:0.005369
# [361]	train-rmse:0.002582	valid-rmse:0.005365
# [362]	train-rmse:0.002582	valid-rmse:0.005365
# [363]	train-rmse:0.002582	valid-rmse:0.005365
# [364]	train-rmse:0.002582	valid-rmse:0.005365
# [365]	train-rmse:0.002582	valid-rmse:0.005365
# [366]	train-rmse:0.002582	valid-rmse:0.005365
# [367]	train-rmse:0.002582	valid-rmse:0.005365
# [368]	train-rmse:0.002582	valid-rmse:0.005365
# [369]	train-rmse:0.002582	valid-rmse:0.005365
# Stopping. Best iteration:
# [269]	train-rmse:0.00264	valid-rmse:0.005358
#
# 1.4688454138116185
